# %%
import ensemble
import importlib
importlib.reload(ensemble) #this is for notebooks - otherwise I have to restart the kernel every time I change anything

from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import RadiusNeighborsRegressor, KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR

from sklearn.ensemble import RandomForestRegressor

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 5]

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

from sklearn.datasets import make_regression

from helpers import test_CoBEAU_NLPD_, normalized_plot

# %%
X, y = make_regression(n_samples=200, n_features=1, noise=25,random_state=42)

# %%
df = test_CoBEAU_NLPD_(ensemble.BootstrapEnsemble,{},X,y)

# %%
df.describe()
# Out:
#              NLPD  correlation between error and variance  \
# count  100.000000                            1.000000e+02
# mean   -36.017457                            2.051156e-01
# std      0.000000                            1.115816e-16
# min    -36.017457                            2.051156e-01
# 25%    -36.017457                            2.051156e-01
# 50%    -36.017457                            2.051156e-01
# 75%    -36.017457                            2.051156e-01
# max    -36.017457                            2.051156e-01
#
#        coverage probability          rsme
# count          1.000000e+02  1.000000e+02
# mean           4.545455e-01  3.391720e+01
# std            1.673724e-16  7.141223e-15
# min            4.545455e-01  3.391720e+01
# 25%            4.545455e-01  3.391720e+01
# 50%            4.545455e-01  3.391720e+01
# 75%            4.545455e-01  3.391720e+01
# max            4.545455e-01  3.391720e+01

# %%
normalized_plot(df)

# %%
df = test_CoBEAU_NLPD_(ensemble.MixedRegressionEnsemble,{'models' :[DecisionTreeRegressor(),
                                                            LinearRegression(),
                                                            KNeighborsRegressor(),
                                                            MLPRegressor(max_iter=2000),
                                                           SVR()]},X,y)
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
df.describe()
# Out:
#              NLPD  correlation between error and variance  \
# count  100.000000                              100.000000
# mean   -33.492084                                0.570125
# std      0.023894                                0.000788
# min    -33.576556                                0.568138
# 25%    -33.506299                                0.569636
# 50%    -33.491192                                0.570204
# 75%    -33.476773                                0.570583
# max    -33.418859                                0.572665
#
#        coverage probability        rsme
# count          1.000000e+02  100.000000
# mean           4.393939e-01   35.877647
# std            1.115816e-16    0.036440
# min            4.393939e-01   35.778938
# 25%            4.393939e-01   35.853988
# 50%            4.393939e-01   35.881848
# 75%            4.393939e-01   35.903406
# max            4.393939e-01   35.973935

# %%
normalized_plot(df)

# %%
boston  =  load_boston()
y = boston.target
X = boston.data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
df = test_CoBEAU_NLPD_(ensemble.MixedRegressionEnsemble,{'models' :[DecisionTreeRegressor(),
                                                            LinearRegression(),
                                                            KNeighborsRegressor(),
                                                            MLPRegressor(max_iter=2000),
                                                           SVR()]},X,y)

# %%
df.describe()
# Out:
#              NLPD  correlation between error and variance  \
# count  100.000000                              100.000000
# mean    -3.115885                                0.557684
# std      0.411241                                0.102417
# min     -3.950854                                0.265677
# 25%     -3.458940                                0.485045
# 50%     -3.006864                                0.556626
# 75%     -2.758132                                0.606670
# max     -2.542305                                0.844212
#
#        coverage probability        rsme
# count            100.000000  100.000000
# mean               0.798802    6.115874
# std                0.101456    1.345334
# min                0.610778    4.406822
# 25%                0.700599    4.843442
# 50%                0.820359    5.941095
# 75%                0.892216    7.197781
# max                0.970060    9.116867

# %%
df.head()
# Out:
#        NLPD  correlation between error and variance  coverage probability  \
# 0 -2.705775                                0.461243              0.658683
# 1 -2.705775                                0.461243              0.658683
# 2 -3.122668                                0.538975              0.700599
# 3 -2.751310                                0.552116              0.670659
# 4 -2.771499                                0.510750              0.706587
#
#        rsme
# 0  4.780683
# 1  4.780683
# 2  5.285072
# 3  4.411952
# 4  4.801372

# %%
plt.plot(df['NLPD'])
plt.plot(df['correlation between error and variance'])

# %%
normalized_df=(df-df.mean())/df.std()

# %%
plt.plot(normalized_df['NLPD'])
plt.plot(normalized_df['correlation between error and variance'])

# %%
np.corrcoef(normalized_df['NLPD'],normalized_df['correlation between error and variance'])
# Out:
# array([[ 1.        , -0.53233767],
#        [-0.53233767,  1.        ]])

# %%
normalized_plot(df)
